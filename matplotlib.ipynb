# %% [markdown]
# ### Data visualization practice

# %%
from matplotlib.backends.backend_agg import FigureCanvasAgg as FigureCanvas  #import FigureCanvas

# %%
from matplotlib.figure import Figure #import Figure Artist

# %%
fig = Figure()

# %%
canavas = FigureCanvas(fig)

# %%
#create 1000 random numbers using numpy
import numpy as np
x = np.random.randn(1000)

ax = fig.add_subplot(111) #create an axes artist
ax.hist(x, 100)  #generate a histogram of 1000 numbers

#add a title to the fig and save it
ax.set_title("Normal distribution with $\mu=0, \sigma=1$")
fig.savefig('matplotlib_histrogram.png')

# %% [markdown]
# ### Scripting method for pyplot
#
# All the axes, fig methods are automatically imported by pyplot in script layer

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

x = np.random.randn(1000)
plt.hist(x, 100)
plt.title("Normal distribution with $\mu=0, \sigma=1$")
plt.savefig("matplotlib_histogram.png")
plt.show()

# %%
# %matplotlib notebook

# %%
plt.plot(5,5,'o')
# Out:
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# ### %matplotlib inline used to generate figures in jupyter notebook

# %%
plt.ylabel('y')
plt.xlabel('x')
plt.title('plotting Example')
# Out:
# Text(0.5, 1, 'plotting Example')

# %%
import pandas as pd
df = pd.read_csv('train_data-Copy1.csv')

# %%
df.head()
# Out:
#       ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0  25150     360000    2          2         2   25     -1     -1     -1
# 1  13470     240000    2          1         2   46      2      2     -2
# 2   3092     320000    2          2         1   41      0      0      0
# 3  13973      50000    2          2         2   24     -1     -1     -2
# 4  10567      80000    1          3         1   52     -1      0      0
#
#    PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0     -1  ...       3435       8870       2020     12590      3479      3446
# 1     -1  ...       2240       1681       2267         0         0      2240
# 2      0  ...      35409      35036      35939      5000      2000      2000
# 3     -2  ...          0          0          0         0         0         0
# 4      0  ...      20561      21261      21457      1500      1500      1500
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default_payment_next_month
# ...

# %%
df[['PAY_AMT3','PAY_AMT4']].plot(kind = "line")
# Out:
# <img src="data:image/png;base64,..." width="432">
